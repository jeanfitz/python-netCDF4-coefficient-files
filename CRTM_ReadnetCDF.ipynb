# %%
from netCDF4 import Dataset

# %%
crtmdat = Dataset("CloudCoeff_TAMU-07SEp2015.nc","r",format="netCDF")

# %%
print(crtmdat.variables)
# Out:
# {'Frequency_MW': <class 'netCDF4._netCDF4.Variable'>
# float64 Frequency_MW(n_MW_Frequencies)
#     long_name: Frequency
#     description: Microwave frequency LUT dimension vector
#     units: GigaHertz (GHz)
#     _FillValue: 0.0
# unlimited dimensions:
# current shape = (31,)
# filling on, 'Frequency_IR': <class 'netCDF4._netCDF4.Variable'>
# float64 Frequency_IR(n_IR_Frequencies)
#     long_name: Frequency
#     description: Infrared frequency LUT dimension vector
#     units: Inverse centimetres (cm^-1)
#     _FillValue: 0.0
# unlimited dimensions:
# current shape = (61,)
# filling on, 'Reff_MW': <class 'netCDF4._netCDF4.Variable'>
# float64 Reff_MW(n_MW_Radii)
#     long_name: Effective radius
#     description: Microwave effective radius LUT dimension vector
#     units: Microns (um)
#     _FillValue: 0.0
# unlimited dimensions:
# current shape = (10,)
# filling on, 'Reff_IR': <class 'netCDF4._netCDF4.Variable'>
# float64 Reff_IR(n_IR_Radii)
#     long_name: Effective radius
# ...

# %%
print(crtmdat.dimensions)
# Out:
# {'n_MW_Frequencies': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_MW_Frequencies', size = 31, 'n_MW_Radii': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_MW_Radii', size = 10, 'n_IR_Frequencies': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_IR_Frequencies', size = 61, 'n_IR_Radii': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_IR_Radii', size = 10, 'n_Temperatures': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_Temperatures', size = 5, 'n_Densities': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_Densities', size = 3, 'n_IR_Densities': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_IR_Densities', size = 4, 'n_Legendre_Terms': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_Legendre_Terms', size = 39, 'n_Phase_Elements': <class 'netCDF4._netCDF4.Dimension'>: name = 'n_Phase_Elements', size = 1}
